# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '21493842621',
#   'type': 'PushEvent',
#   'actor': {'id': 22908993,
#    'login': 'Kholid060',
#    'display_login': 'Kholid060',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kholid060',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22908993?'},
#   'repo': {'id': 412741449,
#    'name': 'Kholid060/automa',
#    'url': 'https://api.github.com/repos/Kholid060/automa'},
#   'payload': {'push_id': 9732183171,
#    'size': 29,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5545ab2840c89b03b544c2966cb50492a6450837',
#    'before': 'efa91845930b4054ed0eb1a6993657167a5a1963',
#    'commits': [{'sha': '23502c90be2f370b22bc2dba730e8eaf536cb627',
#      'author': {'email': 'xkonglong@users.noreply.github.com', 'name': '小恐龙'},
#      'message': 'updata 1.8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/23502c90be2f370b22bc2dba730e8eaf536cb627'},
#     {'sha': '72839a65ce1997a738337cdf25007d99c77e493a',
#      'author': {'email': 'xkonglong@users.noreply.github.com', 'name': '小恐龙'},
#      'message': 'updata 1.8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/72839a65ce1997a738337cdf25007d99c77e493a'},
#     {'sha': 'f4b23fabd01e7426379afbb751f8dcdbe8243707',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'Merge pull request #458 from xkonglong/patch-5\n\nupdata 1.8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/f4b23fabd01e7426379afbb751f8dcdbe8243707'},
#     {'sha': '5ae4d2ea6cf5f1b437e19d103f16a4fc8d71e18c',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'Merge pull request #459 from xkonglong/patch-6\n\nupdate 1.8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/5ae4d2ea6cf5f1b437e19d103f16a4fc8d71e18c'},
#     {'sha': '5f702cf1a0a237f9e597726192bb9180bb27406c',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: add reload block',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/5f702cf1a0a237f9e597726192bb9180bb27406c'},
#     {'sha': 'a1c0c57cdf1a8522d21ff4239c4e18307105168c',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'fix: block got deleted when press delete on an input',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/a1c0c57cdf1a8522d21ff4239c4e18307105168c'},
#     {'sha': 'ddff3dedc2c20e02106f9af45779aeaea306462c',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: add delete data block',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/ddff3dedc2c20e02106f9af45779aeaea306462c'},
#     {'sha': '77dc1ef008c64055fdf6fd31754c0db824868c56',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: improve editor autocomplete',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/77dc1ef008c64055fdf6fd31754c0db824868c56'},
#     {'sha': '143feff69f98e7a93c27774a7d4d933eb6bb5812',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'fix: autocomplete replace wrong value',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/143feff69f98e7a93c27774a7d4d933eb6bb5812'},
#     {'sha': '67e4ef5334334ecc304209c34d251ddaae8e3755',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': "Merge branch 'dev' of https://github.com/kholid060/automa into dev",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/67e4ef5334334ecc304209c34d251ddaae8e3755'},
#     {'sha': '9e8bc60be88683f1aa8e6c6729f541560f733f3e',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: update cloud backup UI',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/9e8bc60be88683f1aa8e6c6729f541560f733f3e'},
#     {'sha': 'b95ff3563eb11a20a6e1c87cbb84a904eb30cb9e',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: toggles enable and disable the block',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/b95ff3563eb11a20a6e1c87cbb84a904eb30cb9e'},
#     {'sha': '20755a0daac0f09225d0f5ba8d1e4bf55ccd4038',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'fix: "Reuse last state" not working',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/20755a0daac0f09225d0f5ba8d1e4bf55ccd4038'},
#     {'sha': '08bf629616bf67043f2ebe7145503520c6c3480b',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: auto delete workflow logs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/08bf629616bf67043f2ebe7145503520c6c3480b'},
#     {'sha': '759c74325585fd453f0f7afd0e5db35fa56a1a4c',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: refresh conditions connections',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/759c74325585fd453f0f7afd0e5db35fa56a1a4c'},
#     {'sha': 'b5ca436182136262de85f4738bc32a5e48bda2bf',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'fix: conditions block input',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/b5ca436182136262de85f4738bc32a5e48bda2bf'},
#     {'sha': '68bbba8ea30cc82b3066502b117742f9ba226c16',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: take a screenshot of an element',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/68bbba8ea30cc82b3066502b117742f9ba226c16'},
#     {'sha': '2fec9f0b97509533a1879ae7f0faad8316adf2ae',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: copy and paste block',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/2fec9f0b97509533a1879ae7f0faad8316adf2ae'},
#     {'sha': 'd00e6c624ee4175658d46c16c768921d46cc4e78',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: copy & paste in editor context menu',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/d00e6c624ee4175658d46c16c768921d46cc4e78'},
#     {'sha': '3072a77eb7d1cba8a086c110870cd92b69c60f23',
#      'author': {'email': 'Kholid060@gmail.com', 'name': 'Ahmad Kholid'},
#      'message': 'feat: add "timestamp" format in `$date` function',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Kholid060/automa/commits/3072a77eb7d1cba8a086c110870cd92b69c60f23'}]},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z'},
#  {'id': '21493842632',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 158584495,
#    'name': 'mgenware/to-type-string',
#    'url': 'https://api.github.com/repos/mgenware/to-type-string'},
#   'payload': {'action': 'closed',
#    'number': 14,
#    'pull_request': {'url': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14',
#     'id': 887899234,
#     'node_id': 'PR_kwDOCXPOr8407ERi',
#     'html_url': 'https://github.com/mgenware/to-type-string/pull/14',
#     'diff_url': 'https://github.com/mgenware/to-type-string/pull/14.diff',
#     'patch_url': 'https://github.com/mgenware/to-type-string/pull/14.patch',
#     'issue_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/14',
#     'number': 14,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump minimist from 1.2.5 to 1.2.6',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [minimist](https://github.com/substack/minimist) from 1.2.5 to 1.2.6.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/substack/minimist/commit/7efb22a518b53b06f5b02a1038a88bd6290c2846"><code>7efb22a</code></a> 1.2.6</li>\n<li><a href="https://github.com/substack/minimist/commit/ef88b9325f77b5ee643ccfc97e2ebda577e4c4e2"><code>ef88b93</code></a> security notice for additional prototype pollution issue</li>\n<li><a href="https://github.com/substack/minimist/commit/c2b981977fa834b223b408cfb860f933c9811e4d"><code>c2b9819</code></a> isConstructorOrProto adapted from PR</li>\n<li><a href="https://github.com/substack/minimist/commit/bc8ecee43875261f4f17eb20b1243d3ed15e70eb"><code>bc8ecee</code></a> test from prototype pollution PR</li>\n<li>See full diff in <a href="https://github.com/substack/minimist/compare/1.2.5...1.2.6">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=minimist&package-manager=npm_and_yarn&previous-version=1.2.5&new-version=1.2.6)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/mgenware/to-type-string/network/alerts).\n\n</details>',
#     'created_at': '2022-03-24T03:50:56Z',
#     'updated_at': '2022-04-27T09:44:26Z',
#     'closed_at': '2022-04-27T09:44:26Z',
#     'merged_at': None,
#     'merge_commit_sha': '42146bf3dba87316c0af926ab76a905c0deac45c',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1653118288,
#       'node_id': 'MDU6TGFiZWwxNjUzMTE4Mjg4',
#       'url': 'https://api.github.com/repos/mgenware/to-type-string/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14/commits',
#     'review_comments_url': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14/comments',
#     'review_comment_url': 'https://api.github.com/repos/mgenware/to-type-string/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/14/comments',
#     'statuses_url': 'https://api.github.com/repos/mgenware/to-type-string/statuses/18006ef040bc842b901e4657cdbeee792673af70',
#     'head': {'label': 'mgenware:dependabot/npm_and_yarn/minimist-1.2.6',
#      'ref': 'dependabot/npm_and_yarn/minimist-1.2.6',
#      'sha': '18006ef040bc842b901e4657cdbeee792673af70',
#      'user': {'login': 'mgenware',
#       'id': 11565096,
#       'node_id': 'MDQ6VXNlcjExNTY1MDk2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11565096?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mgenware',
#       'html_url': 'https://github.com/mgenware',
#       'followers_url': 'https://api.github.com/users/mgenware/followers',
#       'following_url': 'https://api.github.com/users/mgenware/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mgenware/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mgenware/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mgenware/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mgenware/orgs',
#       'repos_url': 'https://api.github.com/users/mgenware/repos',
#       'events_url': 'https://api.github.com/users/mgenware/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mgenware/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 158584495,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTg1ODQ0OTU=',
#       'name': 'to-type-string',
#       'full_name': 'mgenware/to-type-string',
#       'private': False,
#       'owner': {'login': 'mgenware',
#        'id': 11565096,
#        'node_id': 'MDQ6VXNlcjExNTY1MDk2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11565096?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mgenware',
#        'html_url': 'https://github.com/mgenware',
#        'followers_url': 'https://api.github.com/users/mgenware/followers',
#        'following_url': 'https://api.github.com/users/mgenware/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mgenware/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mgenware/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mgenware/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mgenware/orgs',
#        'repos_url': 'https://api.github.com/users/mgenware/repos',
#        'events_url': 'https://api.github.com/users/mgenware/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mgenware/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mgenware/to-type-string',
#       'description': 'Get type description of a JavaScript variable',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mgenware/to-type-string',
#       'forks_url': 'https://api.github.com/repos/mgenware/to-type-string/forks',
#       'keys_url': 'https://api.github.com/repos/mgenware/to-type-string/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mgenware/to-type-string/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mgenware/to-type-string/teams',
#       'hooks_url': 'https://api.github.com/repos/mgenware/to-type-string/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mgenware/to-type-string/events',
#       'assignees_url': 'https://api.github.com/repos/mgenware/to-type-string/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mgenware/to-type-string/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mgenware/to-type-string/tags',
#       'blobs_url': 'https://api.github.com/repos/mgenware/to-type-string/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mgenware/to-type-string/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mgenware/to-type-string/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mgenware/to-type-string/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mgenware/to-type-string/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mgenware/to-type-string/languages',
#       'stargazers_url': 'https://api.github.com/repos/mgenware/to-type-string/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mgenware/to-type-string/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mgenware/to-type-string/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mgenware/to-type-string/subscription',
#       'commits_url': 'https://api.github.com/repos/mgenware/to-type-string/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mgenware/to-type-string/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mgenware/to-type-string/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mgenware/to-type-string/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mgenware/to-type-string/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mgenware/to-type-string/merges',
#       'archive_url': 'https://api.github.com/repos/mgenware/to-type-string/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mgenware/to-type-string/downloads',
#       'issues_url': 'https://api.github.com/repos/mgenware/to-type-string/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mgenware/to-type-string/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mgenware/to-type-string/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mgenware/to-type-string/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mgenware/to-type-string/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mgenware/to-type-string/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mgenware/to-type-string/deployments',
#       'created_at': '2018-11-21T17:33:05Z',
#       'updated_at': '2022-04-27T09:43:50Z',
#       'pushed_at': '2022-04-27T09:44:24Z',
#       'git_url': 'git://github.com/mgenware/to-type-string.git',
#       'ssh_url': 'git@github.com:mgenware/to-type-string.git',
#       'clone_url': 'https://github.com/mgenware/to-type-string.git',
#       'svn_url': 'https://github.com/mgenware/to-type-string',
#       'homepage': None,
#       'size': 380,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'mgenware:main',
#      'ref': 'main',
#      'sha': 'c1a36783b1e900380ebf903e2327e88111aefcf4',
#      'user': {'login': 'mgenware',
#       'id': 11565096,
#       'node_id': 'MDQ6VXNlcjExNTY1MDk2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11565096?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mgenware',
#       'html_url': 'https://github.com/mgenware',
#       'followers_url': 'https://api.github.com/users/mgenware/followers',
#       'following_url': 'https://api.github.com/users/mgenware/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mgenware/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mgenware/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mgenware/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mgenware/orgs',
#       'repos_url': 'https://api.github.com/users/mgenware/repos',
#       'events_url': 'https://api.github.com/users/mgenware/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mgenware/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 158584495,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTg1ODQ0OTU=',
#       'name': 'to-type-string',
#       'full_name': 'mgenware/to-type-string',
#       'private': False,
#       'owner': {'login': 'mgenware',
#        'id': 11565096,
#        'node_id': 'MDQ6VXNlcjExNTY1MDk2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11565096?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mgenware',
#        'html_url': 'https://github.com/mgenware',
#        'followers_url': 'https://api.github.com/users/mgenware/followers',
#        'following_url': 'https://api.github.com/users/mgenware/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mgenware/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mgenware/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mgenware/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mgenware/orgs',
#        'repos_url': 'https://api.github.com/users/mgenware/repos',
#        'events_url': 'https://api.github.com/users/mgenware/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mgenware/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mgenware/to-type-string',
#       'description': 'Get type description of a JavaScript variable',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mgenware/to-type-string',
#       'forks_url': 'https://api.github.com/repos/mgenware/to-type-string/forks',
#       'keys_url': 'https://api.github.com/repos/mgenware/to-type-string/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mgenware/to-type-string/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mgenware/to-type-string/teams',
#       'hooks_url': 'https://api.github.com/repos/mgenware/to-type-string/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mgenware/to-type-string/events',
#       'assignees_url': 'https://api.github.com/repos/mgenware/to-type-string/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mgenware/to-type-string/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mgenware/to-type-string/tags',
#       'blobs_url': 'https://api.github.com/repos/mgenware/to-type-string/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mgenware/to-type-string/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mgenware/to-type-string/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mgenware/to-type-string/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mgenware/to-type-string/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mgenware/to-type-string/languages',
#       'stargazers_url': 'https://api.github.com/repos/mgenware/to-type-string/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mgenware/to-type-string/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mgenware/to-type-string/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mgenware/to-type-string/subscription',
#       'commits_url': 'https://api.github.com/repos/mgenware/to-type-string/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mgenware/to-type-string/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mgenware/to-type-string/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mgenware/to-type-string/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mgenware/to-type-string/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mgenware/to-type-string/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mgenware/to-type-string/merges',
#       'archive_url': 'https://api.github.com/repos/mgenware/to-type-string/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mgenware/to-type-string/downloads',
#       'issues_url': 'https://api.github.com/repos/mgenware/to-type-string/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mgenware/to-type-string/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mgenware/to-type-string/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mgenware/to-type-string/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mgenware/to-type-string/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mgenware/to-type-string/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mgenware/to-type-string/deployments',
#       'created_at': '2018-11-21T17:33:05Z',
#       'updated_at': '2022-04-27T09:43:50Z',
#       'pushed_at': '2022-04-27T09:44:24Z',
#       'git_url': 'git://github.com/mgenware/to-type-string.git',
#       'ssh_url': 'git@github.com:mgenware/to-type-string.git',
#       'clone_url': 'https://github.com/mgenware/to-type-string.git',
#       'svn_url': 'https://github.com/mgenware/to-type-string',
#       'homepage': None,
#       'size': 380,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14'},
#      'html': {'href': 'https://github.com/mgenware/to-type-string/pull/14'},
#      'issue': {'href': 'https://api.github.com/repos/mgenware/to-type-string/issues/14'},
#      'comments': {'href': 'https://api.github.com/repos/mgenware/to-type-string/issues/14/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mgenware/to-type-string/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mgenware/to-type-string/pulls/14/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mgenware/to-type-string/statuses/18006ef040bc842b901e4657cdbeee792673af70'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': False,
#     'rebaseable': False,
#     'mergeable_state': 'dirty',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z'},
#  {'id': '21493842663',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 302738118,
#    'name': 'givefood/data',
#    'url': 'https://api.github.com/repos/givefood/data'},
#   'payload': {'push_id': 9732183205,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1ef717ae5a970e7bde5bad3282790369ae464e46',
#    'before': 'dc774109e32ec0f7910c44da94e7885ec5aef766',
#    'commits': [{'sha': '1ef717ae5a970e7bde5bad3282790369ae464e46',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated'},
#      'message': 'Latest need data: Wed Apr 27 09:44:25 UTC 2022',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/givefood/data/commits/1ef717ae5a970e7bde5bad3282790369ae464e46'}]},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z',
#   'org': {'id': 64801578,
#    'login': 'givefood',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/givefood',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64801578?'}},
#  {'id': '21493842624',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 47809275,
#    'login': 'moayed-mustafa',
#    'display_login': 'moayed-mustafa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moayed-mustafa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?'},
#   'repo': {'id': 480981744,
#    'name': 'moayed-mustafa/github-users',
#    'url': 'https://api.github.com/repos/moayed-mustafa/github-users'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/comments/859593980',
#     'pull_request_review_id': 954610151,
#     'id': 859593980,
#     'node_id': 'PRRC_kwDOHKsy8M4zPFz8',
#     'diff_hunk': '@@ -0,0 +1,35 @@\n+\n+export const placeHolderData = {\n+  avatar_url: "https://avatars.githubusercontent.com/u/47809275?v=4",\n+  bio: null,\n+  blog: "",\n+  company: null,\n+  created_at: "2019-02-20T07:14:41Z",\n+  email: null,\n+  events_url: "https://api.github.com/users/moayed-mustafa/events{/privacy}",\n+  followers: 4,\n+  followers_url: "https://api.github.com/users/moayed-mustafa/followers",\n+  following: 19,\n+  following_url: "https://api.github.com/users/moayed-mustafa/following{/other_user}",\n+  gists_url: "https://api.github.com/users/moayed-mustafa/gists{/gist_id}",\n+  gravatar_id: "",\n+  hireable: true,\n+  html_url: "https://github.com/moayed-mustafa",\n+  id: 47809275,\n+  location: null,\n+  login: "moayed-mustafa",\n+  name: "Moayed Mustafa",\n+  node_id: "MDQ6VXNlcjQ3ODA5Mjc1",\n+  organizations_url: "https://api.github.com/users/moayed-mustafa/orgs",\n+  public_gists: 0,\n+  public_repos: 74,\n+  received_events_url: "https://api.github.com/users/moayed-mustafa/received_events",\n+  repos_url: "https://api.github.com/users/moayed-mustafa/repos",\n+  site_admin: false,\n+  starred_url: "https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}",\n+  subscriptions_url: "https://api.github.com/users/moayed-mustafa/subscriptions",\n+  twitter_username: null,\n+  type: "User",\n+  updated_at: "2022-04-20T20:04:25Z",\n+  url: "https://api.github.com/users/moayed-mustafa",\n+}',
#     'path': 'src/data/data.tsx',
#     'position': 35,
#     'original_position': 35,
#     'commit_id': '8b14927d25d0ad8d0639807597c856e71004a47b',
#     'original_commit_id': '8b14927d25d0ad8d0639807597c856e71004a47b',
#     'user': {'login': 'moayed-mustafa',
#      'id': 47809275,
#      'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/moayed-mustafa',
#      'html_url': 'https://github.com/moayed-mustafa',
#      'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#      'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#      'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#      'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'add line',
#     'created_at': '2022-04-27T09:41:25Z',
#     'updated_at': '2022-04-27T09:44:25Z',
#     'html_url': 'https://github.com/moayed-mustafa/github-users/pull/6#discussion_r859593980',
#     'pull_request_url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/6',
#     'author_association': 'OWNER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/comments/859593980'},
#      'html': {'href': 'https://github.com/moayed-mustafa/github-users/pull/6#discussion_r859593980'},
#      'pull_request': {'href': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/6'}},
#     'reactions': {'url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/comments/859593980/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 35,
#     'original_line': 35,
#     'side': 'RIGHT'},
#    'pull_request': {'url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/6',
#     'id': 917430474,
#     'node_id': 'PR_kwDOHKsy8M42ruDK',
#     'html_url': 'https://github.com/moayed-mustafa/github-users/pull/6',
#     'diff_url': 'https://github.com/moayed-mustafa/github-users/pull/6.diff',
#     'patch_url': 'https://github.com/moayed-mustafa/github-users/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/moayed-mustafa/github-users/issues/6',
#     'number': 6,
#     'state': 'open',
#     'locked': False,
#     'title': 'search api',
#     'user': {'login': 'moayed-mustafa',
#      'id': 47809275,
#      'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/moayed-mustafa',
#      'html_url': 'https://github.com/moayed-mustafa',
#      'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#      'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#      'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#      'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-04-24T12:44:11Z',
#     'updated_at': '2022-04-27T09:44:25Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'adb0a2431d0453ca77eb645096eefd74881be05f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/6/commits',
#     'review_comments_url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/6/comments',
#     'review_comment_url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/moayed-mustafa/github-users/issues/6/comments',
#     'statuses_url': 'https://api.github.com/repos/moayed-mustafa/github-users/statuses/8b14927d25d0ad8d0639807597c856e71004a47b',
#     'head': {'label': 'moayed-mustafa:mm-search-api',
#      'ref': 'mm-search-api',
#      'sha': '8b14927d25d0ad8d0639807597c856e71004a47b',
#      'user': {'login': 'moayed-mustafa',
#       'id': 47809275,
#       'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/moayed-mustafa',
#       'html_url': 'https://github.com/moayed-mustafa',
#       'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#       'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#       'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#       'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#       'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 480981744,
#       'node_id': 'R_kgDOHKsy8A',
#       'name': 'github-users',
#       'full_name': 'moayed-mustafa/github-users',
#       'private': False,
#       'owner': {'login': 'moayed-mustafa',
#        'id': 47809275,
#        'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/moayed-mustafa',
#        'html_url': 'https://github.com/moayed-mustafa',
#        'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#        'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#        'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#        'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#        'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/moayed-mustafa/github-users',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/moayed-mustafa/github-users',
#       'forks_url': 'https://api.github.com/repos/moayed-mustafa/github-users/forks',
#       'keys_url': 'https://api.github.com/repos/moayed-mustafa/github-users/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/moayed-mustafa/github-users/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/moayed-mustafa/github-users/teams',
#       'hooks_url': 'https://api.github.com/repos/moayed-mustafa/github-users/hooks',
#       'issue_events_url': 'https://api.github.com/repos/moayed-mustafa/github-users/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/moayed-mustafa/github-users/events',
#       'assignees_url': 'https://api.github.com/repos/moayed-mustafa/github-users/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/moayed-mustafa/github-users/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/moayed-mustafa/github-users/tags',
#       'blobs_url': 'https://api.github.com/repos/moayed-mustafa/github-users/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/moayed-mustafa/github-users/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/moayed-mustafa/github-users/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/moayed-mustafa/github-users/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/moayed-mustafa/github-users/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/moayed-mustafa/github-users/languages',
#       'stargazers_url': 'https://api.github.com/repos/moayed-mustafa/github-users/stargazers',
#       'contributors_url': 'https://api.github.com/repos/moayed-mustafa/github-users/contributors',
#       'subscribers_url': 'https://api.github.com/repos/moayed-mustafa/github-users/subscribers',
#       'subscription_url': 'https://api.github.com/repos/moayed-mustafa/github-users/subscription',
#       'commits_url': 'https://api.github.com/repos/moayed-mustafa/github-users/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/moayed-mustafa/github-users/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/moayed-mustafa/github-users/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/moayed-mustafa/github-users/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/moayed-mustafa/github-users/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/moayed-mustafa/github-users/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/moayed-mustafa/github-users/merges',
#       'archive_url': 'https://api.github.com/repos/moayed-mustafa/github-users/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/moayed-mustafa/github-users/downloads',
#       'issues_url': 'https://api.github.com/repos/moayed-mustafa/github-users/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/moayed-mustafa/github-users/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/moayed-mustafa/github-users/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/moayed-mustafa/github-users/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/moayed-mustafa/github-users/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/moayed-mustafa/github-users/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/moayed-mustafa/github-users/deployments',
#       'created_at': '2022-04-12T21:42:45Z',
#       'updated_at': '2022-04-17T21:36:51Z',
#       'pushed_at': '2022-04-27T09:35:20Z',
#       'git_url': 'git://github.com/moayed-mustafa/github-users.git',
#       'ssh_url': 'git@github.com:moayed-mustafa/github-users.git',
#       'clone_url': 'https://github.com/moayed-mustafa/github-users.git',
#       'svn_url': 'https://github.com/moayed-mustafa/github-users',
#       'homepage': None,
#       'size': 491,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'moayed-mustafa:master',
#      'ref': 'master',
#      'sha': '1ee4b709de847270d4da4ba74287c604b16f9a9b',
#      'user': {'login': 'moayed-mustafa',
#       'id': 47809275,
#       'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/moayed-mustafa',
#       'html_url': 'https://github.com/moayed-mustafa',
#       'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#       'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#       'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#       'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#       'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 480981744,
#       'node_id': 'R_kgDOHKsy8A',
#       'name': 'github-users',
#       'full_name': 'moayed-mustafa/github-users',
#       'private': False,
#       'owner': {'login': 'moayed-mustafa',
#        'id': 47809275,
#        'node_id': 'MDQ6VXNlcjQ3ODA5Mjc1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47809275?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/moayed-mustafa',
#        'html_url': 'https://github.com/moayed-mustafa',
#        'followers_url': 'https://api.github.com/users/moayed-mustafa/followers',
#        'following_url': 'https://api.github.com/users/moayed-mustafa/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/moayed-mustafa/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/moayed-mustafa/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/moayed-mustafa/subscriptions',
#        'organizations_url': 'https://api.github.com/users/moayed-mustafa/orgs',
#        'repos_url': 'https://api.github.com/users/moayed-mustafa/repos',
#        'events_url': 'https://api.github.com/users/moayed-mustafa/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/moayed-mustafa/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/moayed-mustafa/github-users',
# ...
#       'events_url': 'https://api.github.com/users/canvasland-nft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/canvasland-nft/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 480289210,
#       'node_id': 'R_kgDOHKChug',
#       'name': 'marketplace',
#       'full_name': 'canvasland-nft/marketplace',
#       'private': False,
#       'owner': {'login': 'canvasland-nft',
#        'id': 103397907,
#        'node_id': 'U_kgDOBim6Ew',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/103397907?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/canvasland-nft',
#        'html_url': 'https://github.com/canvasland-nft',
#        'followers_url': 'https://api.github.com/users/canvasland-nft/followers',
#        'following_url': 'https://api.github.com/users/canvasland-nft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/canvasland-nft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/canvasland-nft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/canvasland-nft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/canvasland-nft/orgs',
#        'repos_url': 'https://api.github.com/users/canvasland-nft/repos',
#        'events_url': 'https://api.github.com/users/canvasland-nft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/canvasland-nft/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/canvasland-nft/marketplace',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/canvasland-nft/marketplace',
#       'forks_url': 'https://api.github.com/repos/canvasland-nft/marketplace/forks',
#       'keys_url': 'https://api.github.com/repos/canvasland-nft/marketplace/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/canvasland-nft/marketplace/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/canvasland-nft/marketplace/teams',
#       'hooks_url': 'https://api.github.com/repos/canvasland-nft/marketplace/hooks',
#       'issue_events_url': 'https://api.github.com/repos/canvasland-nft/marketplace/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/canvasland-nft/marketplace/events',
#       'assignees_url': 'https://api.github.com/repos/canvasland-nft/marketplace/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/canvasland-nft/marketplace/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/canvasland-nft/marketplace/tags',
#       'blobs_url': 'https://api.github.com/repos/canvasland-nft/marketplace/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/canvasland-nft/marketplace/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/canvasland-nft/marketplace/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/canvasland-nft/marketplace/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/canvasland-nft/marketplace/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/canvasland-nft/marketplace/languages',
#       'stargazers_url': 'https://api.github.com/repos/canvasland-nft/marketplace/stargazers',
#       'contributors_url': 'https://api.github.com/repos/canvasland-nft/marketplace/contributors',
#       'subscribers_url': 'https://api.github.com/repos/canvasland-nft/marketplace/subscribers',
#       'subscription_url': 'https://api.github.com/repos/canvasland-nft/marketplace/subscription',
#       'commits_url': 'https://api.github.com/repos/canvasland-nft/marketplace/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/canvasland-nft/marketplace/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/canvasland-nft/marketplace/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/canvasland-nft/marketplace/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/canvasland-nft/marketplace/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/canvasland-nft/marketplace/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/canvasland-nft/marketplace/merges',
#       'archive_url': 'https://api.github.com/repos/canvasland-nft/marketplace/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/canvasland-nft/marketplace/downloads',
#       'issues_url': 'https://api.github.com/repos/canvasland-nft/marketplace/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/canvasland-nft/marketplace/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/canvasland-nft/marketplace/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/canvasland-nft/marketplace/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/canvasland-nft/marketplace/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/canvasland-nft/marketplace/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/canvasland-nft/marketplace/deployments',
#       'created_at': '2022-04-11T08:20:47Z',
#       'updated_at': '2022-04-11T09:10:11Z',
#       'pushed_at': '2022-04-27T09:30:07Z',
#       'git_url': 'git://github.com/canvasland-nft/marketplace.git',
#       'ssh_url': 'git@github.com:canvasland-nft/marketplace.git',
#       'clone_url': 'https://github.com/canvasland-nft/marketplace.git',
#       'svn_url': 'https://github.com/canvasland-nft/marketplace',
#       'homepage': None,
#       'size': 561,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/pulls/19'},
#      'html': {'href': 'https://github.com/canvasland-nft/marketplace/pull/19'},
#      'issue': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/issues/19'},
#      'comments': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/issues/19/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/pulls/19/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/pulls/19/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/canvasland-nft/marketplace/statuses/38a9781c5276f8f1cb289df51f60ba727f49cb61'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z'},
#  {'id': '21493842466',
#   'type': 'CreateEvent',
#   'actor': {'id': 104206747,
#    'login': 'Edgar6991',
#    'display_login': 'Edgar6991',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Edgar6991',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104206747?'},
#   'repo': {'id': 486133338,
#    'name': 'Edgar6991/eshop',
#    'url': 'https://api.github.com/repos/Edgar6991/eshop'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z'},
#  {'id': '21493842421',
#   'type': 'PushEvent',
#   'actor': {'id': 2016594,
#    'login': 'zhaoyongjie',
#    'display_login': 'zhaoyongjie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhaoyongjie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2016594?'},
#   'repo': {'id': 39464018,
#    'name': 'apache/superset',
#    'url': 'https://api.github.com/repos/apache/superset'},
#   'payload': {'push_id': 9732182159,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f9d28a107266aff1fea10056ec69d437981df1bd',
#    'before': 'ad878b07e48edb4059fbc6620accd2f7b993ae4b',
#    'commits': [{'sha': 'f9d28a107266aff1fea10056ec69d437981df1bd',
#      'author': {'email': '750188453@qq.com', 'name': 'Stephen Liu'},
#      'message': 'chore: add eslint custom plugin to prevent translation variables (#19828)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/apache/superset/commits/f9d28a107266aff1fea10056ec69d437981df1bd'}]},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '21493842478',
#   'type': 'CreateEvent',
#   'actor': {'id': 36091631,
#    'login': 'M4TTRX',
#    'display_login': 'M4TTRX',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/M4TTRX',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36091631?'},
#   'repo': {'id': 480874288,
#    'name': 'Liderbord/liderbord',
#    'url': 'https://api.github.com/repos/Liderbord/liderbord'},
#   'payload': {'ref': 'security-and-packages',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'The SMART project for INSA Lyon',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z',
#   'org': {'id': 100754601,
#    'login': 'Liderbord',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Liderbord',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100754601?'}},
#  {'id': '21493842453',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 44348300,
#    'login': 'joppevos',
#    'display_login': 'joppevos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joppevos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44348300?'},
#   'repo': {'id': 33884891,
#    'name': 'apache/airflow',
#    'url': 'https://api.github.com/repos/apache/airflow'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/apache/airflow/issues/23083',
#     'repository_url': 'https://api.github.com/repos/apache/airflow',
#     'labels_url': 'https://api.github.com/repos/apache/airflow/issues/23083/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/apache/airflow/issues/23083/comments',
#     'events_url': 'https://api.github.com/repos/apache/airflow/issues/23083/events',
#     'html_url': 'https://github.com/apache/airflow/issues/23083',
#     'id': 1208436965,
#     'node_id': 'I_kwDOAgUK285IB0jl',
#     'number': 23083,
#     'title': 'Breeze: Running integration tests in Breeze',
#     'user': {'login': 'potiuk',
#      'id': 595491,
#      'node_id': 'MDQ6VXNlcjU5NTQ5MQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/595491?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/potiuk',
#      'html_url': 'https://github.com/potiuk',
#      'followers_url': 'https://api.github.com/users/potiuk/followers',
#      'following_url': 'https://api.github.com/users/potiuk/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/potiuk/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/potiuk/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/potiuk/subscriptions',
#      'organizations_url': 'https://api.github.com/users/potiuk/orgs',
#      'repos_url': 'https://api.github.com/users/potiuk/repos',
#      'events_url': 'https://api.github.com/users/potiuk/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/potiuk/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2022-04-19T14:17:28Z',
#     'updated_at': '2022-04-27T09:44:26Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'body': 'We should be able to run integration tests with Breeze - this is extension of `test` unit tests command that should allow to enable --integrations (same as in Shell) and run the tests with only the integration tests selected.',
#     'reactions': {'url': 'https://api.github.com/repos/apache/airflow/issues/23083/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/apache/airflow/issues/23083/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/apache/airflow/issues/comments/1110794692',
#     'html_url': 'https://github.com/apache/airflow/issues/23083#issuecomment-1110794692',
#     'issue_url': 'https://api.github.com/repos/apache/airflow/issues/23083',
#     'id': 1110794692,
#     'node_id': 'IC_kwDOAgUK285CNWHE',
#     'user': {'login': 'joppevos',
#      'id': 44348300,
#      'node_id': 'MDQ6VXNlcjQ0MzQ4MzAw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44348300?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/joppevos',
#      'html_url': 'https://github.com/joppevos',
#      'followers_url': 'https://api.github.com/users/joppevos/followers',
#      'following_url': 'https://api.github.com/users/joppevos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/joppevos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/joppevos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/joppevos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/joppevos/orgs',
#      'repos_url': 'https://api.github.com/users/joppevos/repos',
#      'events_url': 'https://api.github.com/users/joppevos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/joppevos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-04-27T09:44:25Z',
#     'updated_at': '2022-04-27T09:44:25Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '@potiuk I tried to make a start this morning, but some things are not clear to me yet. \r\n\r\nWe want to run pytest in our container. Too run `docker exec ...pytest`, the container needs to be running. \r\nDo we want `breeze tests` to spin up the container? \r\nA logic like the following:\r\n```\r\ncheck if container is running\r\n...\r\nif not, spin up container detached\r\nexec pytest in container\r\n...\r\nforward pytest results to stdout\r\nstop de container\r\n```\r\n\r\nIn `breeze-legacy`, we ask the user to first spin up the container himself, detached. \r\nI cannot find a command in the new breeze where we can spin the container up easily detached. Then we need to provide a command for that too i guess. something like `docker-compose up -d` wrapped with `breeze up`?\r\n\r\nThanks for the help and rubber ducking 🦆 \r\n',
#     'reactions': {'url': 'https://api.github.com/repos/apache/airflow/issues/comments/1110794692/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-27T09:44:26Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   21493842621                      PushEvent
# 1   21493842632               PullRequestEvent
# 2   21493842663                      PushEvent
# 3   21493842624  PullRequestReviewCommentEvent
# 4   21493842571                      PushEvent
# 5   21493842593                      PushEvent
# 6   21493842577                    CreateEvent
# 7   21493842607                    CreateEvent
# 8   21493842618  PullRequestReviewCommentEvent
# 9   21493842554                      PushEvent
# 10  21493842572  PullRequestReviewCommentEvent
# 11  21493842545               PullRequestEvent
# 12  21493842598  PullRequestReviewCommentEvent
# 13  21493842604  PullRequestReviewCommentEvent
# 14  21493842542                      PushEvent
# 15  21493842502                      PushEvent
# 16  21493842561                    MemberEvent
# 17  21493842486               PullRequestEvent
# 18  21493842472                      PushEvent
# 19  21493842511              IssueCommentEvent
# 20  21493842519                    CreateEvent
# 21  21493842540  PullRequestReviewCommentEvent
# 22  21493842458         PullRequestReviewEvent
# 23  21493842480                      PushEvent
# 24  21493842500                      PushEvent
# 25  21493842504         PullRequestReviewEvent
# 26  21493842466                    CreateEvent
# 27  21493842421                      PushEvent
# 28  21493842478                    CreateEvent
# 29  21493842453              IssueCommentEvent
#
#                                                 actor  \
# 0   {'id': 22908993, 'login': 'Kholid060', 'displa...
# 1   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 2   {'id': 41898282, 'login': 'github-actions[bot]...
# 3   {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 4   {'id': 41898282, 'login': 'github-actions[bot]...
# 5   {'id': 25459913, 'login': 'idaame', 'display_l...
# 6   {'id': 56908037, 'login': 'lohhuiqi', 'display...
# 7   {'id': 81749100, 'login': 'srikanth-automation...
# 8   {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 9   {'id': 2687598, 'login': 'milesholt', 'display...
# 10  {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 11  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 12  {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 13  {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 14  {'id': 77894439, 'login': 'JosephKS10', 'displ...
# 15  {'id': 87108942, 'login': 'shaiknagoorvali1080...
# 16  {'id': 101546990, 'login': 'avanish009', 'disp...
# 17  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 18  {'id': 64401158, 'login': 'fkworthy', 'display...
# 19  {'id': 85470126, 'login': 'yoonho-shin', 'disp...
# 20  {'id': 62989315, 'login': 'LijiaMALab', 'displ...
# 21  {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 22  {'id': 47809275, 'login': 'moayed-mustafa', 'd...
# 23  {'id': 70049060, 'login': 'jiangwenqiyu', 'dis...
# 24  {'id': 96470102, 'login': 'DarekZincani', 'dis...
# 25  {'id': 103410278, 'login': 'pracheebapate', 'd...
# 26  {'id': 104206747, 'login': 'Edgar6991', 'displ...
# 27  {'id': 2016594, 'login': 'zhaoyongjie', 'displ...
# 28  {'id': 36091631, 'login': 'M4TTRX', 'display_l...
# 29  {'id': 44348300, 'login': 'joppevos', 'display...
#
#                                                  repo  \
# 0   {'id': 412741449, 'name': 'Kholid060/automa', ...
# 1   {'id': 158584495, 'name': 'mgenware/to-type-st...
# 2   {'id': 302738118, 'name': 'givefood/data', 'ur...
# 3   {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 4   {'id': 433420925, 'name': 'an-halim/Last-Earth...
# 5   {'id': 224639942, 'name': 'navikt/familie-ba-s...
# 6   {'id': 486133340, 'name': 'lohhuiqi/lohhuiqi',...
# 7   {'id': 486133333, 'name': 'srikanth-automation...
# 8   {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 9   {'id': 247480564, 'name': 'milesholt/autotrade...
# 10  {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 11  {'id': 158584495, 'name': 'mgenware/to-type-st...
# 12  {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 13  {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 14  {'id': 472359397, 'name': 'JosephKS10/pharmacy...
# 15  {'id': 484387464, 'name': 'shaiknagoorvali1080...
# 16  {'id': 485907722, 'name': 'avanish009/Sprint2-...
# 17  {'id': 158584495, 'name': 'mgenware/to-type-st...
# 18  {'id': 347547076, 'name': 'fkworthy/fkworthy',...
# 19  {'id': 378035269, 'name': 'yoonho-shin/YouComp...
# 20  {'id': 486133339, 'name': 'LijiaMALab/PEGUIDE'...
# 21  {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 22  {'id': 480981744, 'name': 'moayed-mustafa/gith...
# 23  {'id': 483173615, 'name': 'jiangwenqiyu/xfsPro...
# 24  {'id': 486110448, 'name': 'DarekZincani/AEROPO...
# 25  {'id': 480289210, 'name': 'canvasland-nft/mark...
# 26  {'id': 486133338, 'name': 'Edgar6991/eshop', '...
# 27  {'id': 39464018, 'name': 'apache/superset', 'u...
# 28  {'id': 480874288, 'name': 'Liderbord/liderbord...
# 29  {'id': 33884891, 'name': 'apache/airflow', 'ur...
#
#                                               payload  public  \
# 0   {'push_id': 9732183171, 'size': 29, 'distinct_...    True
# 1   {'action': 'closed', 'number': 14, 'pull_reque...    True
# 2   {'push_id': 9732183205, 'size': 1, 'distinct_s...    True
# 3   {'action': 'created', 'comment': {'url': 'http...    True
# 4   {'push_id': 9732183157, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 9732183167, 'size': 1, 'distinct_s...    True
# 6   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 7   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 8   {'action': 'created', 'comment': {'url': 'http...    True
# 9   {'push_id': 9732183158, 'size': 1, 'distinct_s...    True
# 10  {'action': 'created', 'comment': {'url': 'http...    True
# 11  {'action': 'closed', 'number': 12, 'pull_reque...    True
# 12  {'action': 'created', 'comment': {'url': 'http...    True
# 13  {'action': 'created', 'comment': {'url': 'http...    True
# 14  {'push_id': 9732183148, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 9732183125, 'size': 1, 'distinct_s...    True
# 16  {'member': {'login': 'SHUBHUh', 'id': 10154794...    True
# 17  {'action': 'closed', 'number': 11, 'pull_reque...    True
# 18  {'push_id': 9732183113, 'size': 1, 'distinct_s...    True
# 19  {'action': 'created', 'issue': {'url': 'https:...    True
# 20  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 21  {'action': 'created', 'comment': {'url': 'http...    True
# 22  {'action': 'created', 'review': {'id': 9546101...    True
# 23  {'push_id': 9732183116, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 9732183122, 'size': 1, 'distinct_s...    True
# 25  {'action': 'created', 'review': {'id': 9546155...    True
# 26  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 27  {'push_id': 9732182159, 'size': 1, 'distinct_s...    True
# 28  {'ref': 'security-and-packages', 'ref_type': '...    True
# 29  {'action': 'created', 'issue': {'url': 'https:...    True
#
#               created_at                                                org
# 0   2022-04-27T09:44:26Z                                                NaN
# 1   2022-04-27T09:44:26Z                                                NaN
# 2   2022-04-27T09:44:26Z  {'id': 64801578, 'login': 'givefood', 'gravata...
# 3   2022-04-27T09:41:25Z                                                NaN
# 4   2022-04-27T09:44:26Z                                                NaN
# 5   2022-04-27T09:44:26Z  {'id': 11848947, 'login': 'navikt', 'gravatar_...
# 6   2022-04-27T09:44:26Z                                                NaN
# 7   2022-04-27T09:44:26Z                                                NaN
# 8   2022-04-27T09:43:03Z                                                NaN
# 9   2022-04-27T09:44:26Z                                                NaN
# 10  2022-04-27T09:40:50Z                                                NaN
# 11  2022-04-27T09:44:26Z                                                NaN
# 12  2022-04-27T09:42:56Z                                                NaN
# 13  2022-04-27T09:41:59Z                                                NaN
# 14  2022-04-27T09:44:26Z                                                NaN
# 15  2022-04-27T09:44:26Z                                                NaN
# 16  2022-04-27T09:44:26Z                                                NaN
# 17  2022-04-27T09:44:26Z                                                NaN
# 18  2022-04-27T09:44:26Z                                                NaN
# 19  2022-04-27T09:44:26Z                                                NaN
# 20  2022-04-27T09:44:26Z                                                NaN
# 21  2022-04-27T09:40:30Z                                                NaN
# 22  2022-04-27T09:44:26Z                                                NaN
# 23  2022-04-27T09:44:26Z                                                NaN
# 24  2022-04-27T09:44:26Z                                                NaN
# 25  2022-04-27T09:44:26Z                                                NaN
# 26  2022-04-27T09:44:26Z                                                NaN
# 27  2022-04-27T09:44:26Z  {'id': 47359, 'login': 'apache', 'gravatar_id'...
# 28  2022-04-27T09:44:26Z  {'id': 100754601, 'login': 'Liderbord', 'grava...
# 29  2022-04-27T09:44:26Z  {'id': 47359, 'login': 'apache', 'gravatar_id'...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   21493842621                      PushEvent    True  2022-04-27T09:44:26Z
# 1   21493842632               PullRequestEvent    True  2022-04-27T09:44:26Z
# 2   21493842663                      PushEvent    True  2022-04-27T09:44:26Z
# 3   21493842624  PullRequestReviewCommentEvent    True  2022-04-27T09:41:25Z
# 4   21493842571                      PushEvent    True  2022-04-27T09:44:26Z
# 5   21493842593                      PushEvent    True  2022-04-27T09:44:26Z
# 6   21493842577                    CreateEvent    True  2022-04-27T09:44:26Z
# 7   21493842607                    CreateEvent    True  2022-04-27T09:44:26Z
# 8   21493842618  PullRequestReviewCommentEvent    True  2022-04-27T09:43:03Z
# 9   21493842554                      PushEvent    True  2022-04-27T09:44:26Z
# 10  21493842572  PullRequestReviewCommentEvent    True  2022-04-27T09:40:50Z
# 11  21493842545               PullRequestEvent    True  2022-04-27T09:44:26Z
# 12  21493842598  PullRequestReviewCommentEvent    True  2022-04-27T09:42:56Z
# 13  21493842604  PullRequestReviewCommentEvent    True  2022-04-27T09:41:59Z
# 14  21493842542                      PushEvent    True  2022-04-27T09:44:26Z
# 15  21493842502                      PushEvent    True  2022-04-27T09:44:26Z
# 16  21493842561                    MemberEvent    True  2022-04-27T09:44:26Z
# 17  21493842486               PullRequestEvent    True  2022-04-27T09:44:26Z
# 18  21493842472                      PushEvent    True  2022-04-27T09:44:26Z
# 19  21493842511              IssueCommentEvent    True  2022-04-27T09:44:26Z
# 20  21493842519                    CreateEvent    True  2022-04-27T09:44:26Z
# 21  21493842540  PullRequestReviewCommentEvent    True  2022-04-27T09:40:30Z
# 22  21493842458         PullRequestReviewEvent    True  2022-04-27T09:44:26Z
# 23  21493842480                      PushEvent    True  2022-04-27T09:44:26Z
# 24  21493842500                      PushEvent    True  2022-04-27T09:44:26Z
# 25  21493842504         PullRequestReviewEvent    True  2022-04-27T09:44:26Z
# 26  21493842466                    CreateEvent    True  2022-04-27T09:44:26Z
# 27  21493842421                      PushEvent    True  2022-04-27T09:44:26Z
# 28  21493842478                    CreateEvent    True  2022-04-27T09:44:26Z
# 29  21493842453              IssueCommentEvent    True  2022-04-27T09:44:26Z
#
#      actor.id           actor.login   actor.display_login actor.gravatar_id  \
# 0    22908993             Kholid060             Kholid060
# 1    49699333       dependabot[bot]            dependabot
# 2    41898282   github-actions[bot]        github-actions
# 3    47809275        moayed-mustafa        moayed-mustafa
# 4    41898282   github-actions[bot]        github-actions
# 5    25459913                idaame                idaame
# 6    56908037              lohhuiqi              lohhuiqi
# 7    81749100   srikanth-automation   srikanth-automation
# 8    47809275        moayed-mustafa        moayed-mustafa
# 9     2687598             milesholt             milesholt
# 10   47809275        moayed-mustafa        moayed-mustafa
# 11   49699333       dependabot[bot]            dependabot
# 12   47809275        moayed-mustafa        moayed-mustafa
# 13   47809275        moayed-mustafa        moayed-mustafa
# 14   77894439            JosephKS10            JosephKS10
# 15   87108942  shaiknagoorvali10803  shaiknagoorvali10803
# 16  101546990            avanish009            avanish009
# 17   49699333       dependabot[bot]            dependabot
# 18   64401158              fkworthy              fkworthy
# 19   85470126           yoonho-shin           yoonho-shin
# 20   62989315            LijiaMALab            LijiaMALab
# 21   47809275        moayed-mustafa        moayed-mustafa
# 22   47809275        moayed-mustafa        moayed-mustafa
# 23   70049060          jiangwenqiyu          jiangwenqiyu
# 24   96470102          DarekZincani          DarekZincani
# 25  103410278         pracheebapate         pracheebapate
# 26  104206747             Edgar6991             Edgar6991
# 27    2016594           zhaoyongjie           zhaoyongjie
# 28   36091631                M4TTRX                M4TTRX
# 29   44348300              joppevos              joppevos
#
#                                             actor.url  \
# 0              https://api.github.com/users/Kholid060
# 1        https://api.github.com/users/dependabot[bot]
# 2    https://api.github.com/users/github-actions[bot]
# 3         https://api.github.com/users/moayed-mustafa
# 4    https://api.github.com/users/github-actions[bot]
# 5                 https://api.github.com/users/idaame
# 6               https://api.github.com/users/lohhuiqi
# 7    https://api.github.com/users/srikanth-automation
# 8         https://api.github.com/users/moayed-mustafa
# 9              https://api.github.com/users/milesholt
# 10        https://api.github.com/users/moayed-mustafa
# 11       https://api.github.com/users/dependabot[bot]
# 12        https://api.github.com/users/moayed-mustafa
# 13        https://api.github.com/users/moayed-mustafa
# 14            https://api.github.com/users/JosephKS10
# 15  https://api.github.com/users/shaiknagoorvali10803
# 16            https://api.github.com/users/avanish009
# 17       https://api.github.com/users/dependabot[bot]
# 18              https://api.github.com/users/fkworthy
# 19           https://api.github.com/users/yoonho-shin
# 20            https://api.github.com/users/LijiaMALab
# 21        https://api.github.com/users/moayed-mustafa
# 22        https://api.github.com/users/moayed-mustafa
# 23          https://api.github.com/users/jiangwenqiyu
# 24          https://api.github.com/users/DarekZincani
# 25         https://api.github.com/users/pracheebapate
# 26             https://api.github.com/users/Edgar6991
# 27           https://api.github.com/users/zhaoyongjie
# 28                https://api.github.com/users/M4TTRX
# 29              https://api.github.com/users/joppevos
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/22908993?  ...
# 1   https://avatars.githubusercontent.com/u/49699333?  ...
# 2   https://avatars.githubusercontent.com/u/41898282?  ...
# 3   https://avatars.githubusercontent.com/u/47809275?  ...
# 4   https://avatars.githubusercontent.com/u/41898282?  ...
# 5   https://avatars.githubusercontent.com/u/25459913?  ...
# 6   https://avatars.githubusercontent.com/u/56908037?  ...
# 7   https://avatars.githubusercontent.com/u/81749100?  ...
# 8   https://avatars.githubusercontent.com/u/47809275?  ...
# 9    https://avatars.githubusercontent.com/u/2687598?  ...
# 10  https://avatars.githubusercontent.com/u/47809275?  ...
# 11  https://avatars.githubusercontent.com/u/49699333?  ...
# 12  https://avatars.githubusercontent.com/u/47809275?  ...
# 13  https://avatars.githubusercontent.com/u/47809275?  ...
# 14  https://avatars.githubusercontent.com/u/77894439?  ...
# 15  https://avatars.githubusercontent.com/u/87108942?  ...
# 16  https://avatars.githubusercontent.com/u/101546...  ...
# 17  https://avatars.githubusercontent.com/u/49699333?  ...
# 18  https://avatars.githubusercontent.com/u/64401158?  ...
# 19  https://avatars.githubusercontent.com/u/85470126?  ...
# 20  https://avatars.githubusercontent.com/u/62989315?  ...
# 21  https://avatars.githubusercontent.com/u/47809275?  ...
# 22  https://avatars.githubusercontent.com/u/47809275?  ...
# 23  https://avatars.githubusercontent.com/u/70049060?  ...
# 24  https://avatars.githubusercontent.com/u/96470102?  ...
# 25  https://avatars.githubusercontent.com/u/103410...  ...
# 26  https://avatars.githubusercontent.com/u/104206...  ...
# 27   https://avatars.githubusercontent.com/u/2016594?  ...
# 28  https://avatars.githubusercontent.com/u/36091631?  ...
# 29  https://avatars.githubusercontent.com/u/44348300?  ...
#
#           payload.pull_request.assignee.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/fol...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#               payload.pull_request.assignee.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/gis...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#             payload.pull_request.assignee.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/sta...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#       payload.pull_request.assignee.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/sub...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     payload.pull_request.assignee.organizations_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25  https://api.github.com/users/jibrail-idris/orgs
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
#
#              payload.pull_request.assignee.repos_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25  https://api.github.com/users/jibrail-idris/repos
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
#
#              payload.pull_request.assignee.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/eve...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     payload.pull_request.assignee.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/jibrail-idris/rec...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.assignee.type payload.pull_request.assignee.site_admin
# 0                                 NaN                                      NaN
# 1                                 NaN                                      NaN
# 2                                 NaN                                      NaN
# 3                                 NaN                                      NaN
# 4                                 NaN                                      NaN
# 5                                 NaN                                      NaN
# 6                                 NaN                                      NaN
# 7                                 NaN                                      NaN
# 8                                 NaN                                      NaN
# 9                                 NaN                                      NaN
# 10                                NaN                                      NaN
# 11                                NaN                                      NaN
# 12                                NaN                                      NaN
# 13                                NaN                                      NaN
# 14                                NaN                                      NaN
# 15                                NaN                                      NaN
# 16                                NaN                                      NaN
# 17                                NaN                                      NaN
# 18                                NaN                                      NaN
# 19                                NaN                                      NaN
# 20                                NaN                                      NaN
# 21                                NaN                                      NaN
# 22                                NaN                                      NaN
# 23                                NaN                                      NaN
# 24                                NaN                                      NaN
# 25                               User                                    False
# 26                                NaN                                      NaN
# 27                                NaN                                      NaN
# 28                                NaN                                      NaN
# 29                                NaN                                      NaN
#
# [30 rows x 514 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'iss_position': {'longitude': '63.1695', 'latitude': '-21.1683'},
#  'message': 'success',
#  'timestamp': 1651052973}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1645005147,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 651, 'risetime': 1645005884},
#   {'duration': 629, 'risetime': 1645011687},
#   {'duration': 491, 'risetime': 1645017515},
#   {'duration': 101, 'risetime': 1645072364},
#   {'duration': 571, 'risetime': 1645077861}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_33898/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1644965430, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 350, 'risetime': 1644988708}, {'duration': 603, 'risetime': 1644994325}, {'duration': 649, 'risetime': 1645000084}, {'duration': 651, 'risetime': 1645005884}, {'duration': 629, 'risetime': 1645011686}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
